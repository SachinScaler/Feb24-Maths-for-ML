# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinScaler/Feb25-Maths-for-ML/blob/main/Optimization_4_Constrained_optimization%7CLecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

f = lambda x: x**2

## Plot f(x)
x = np.arange(-10, 10, 0.01)
y = f(x)


plt.figure()
plt.title("F(x) = x^2")
plt.plot(x, y)
plt.show()

# %% [markdown]
# Recap

# %%
# This function takes derivative of f at point x
def derivative(x, f): # ab intio method
  delta = 0.0001
  return (f(x + delta) - f(x)) / delta

# This function does exactly one update to my parameter x
def update_step_gd(x, f, lr): # lr -> learning rate, same as \eta
  grad = derivative(x, f)
  new_x = x - lr * grad
  return new_x, grad

# %% [markdown]
# ### Gradient Descent One Step: Plot

# %%
# Step1: randomly parameter intitialize
x_val = -5
learning_rate = 0.1


# Plot function
f = lambda x: x**2
plt.figure()

## Plot f(x)
x = np.linspace(-10, 10, 400)
plt.plot(x, f(x))

# Plot initial guess with tangent line
t_x = np.linspace(x_val - 2, x_val + 2, 10)

# -5 and 5**2: point
plt.plot(x_val, f(x_val), "ro", markersize=5, label="Initial Point")  # Initial point


# Step2: Gradient descent step
new_x, grad = update_step_gd(x_val, f, learning_rate)

# Plot initial Tangent line
plt.plot(t_x, grad * t_x + (f(x_val) - grad * x_val), color="black")

# Plot updated point
plt.plot(new_x, f(new_x), "o", markersize=5, color="orange", label="Updated Point")

print("update p", new_x)
print("Grad",grad)
x_val = new_x
plt.legend()
plt.show()
# Out:
# update p -4.000010000003158
# Grad -9.99989999996842

# %%
# Step1: randomly parameter intitialize
x_val = -5
learning_rate = 0.1

# Step2: Gradient descent step
new_x, grad = update_step_gd(x_val, f, learning_rate)
new_x
# Out:
# -4.000010000003158

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Initialize parameters
x_val = -5

# hyper parameters
learning_rate = 0.1
num_epochs = 20

# Lists to store x values and function values
x_vals = [x_val]
fx_vals = [f(x_val)]

# Step 2: Gradient Descent Loop
for _ in range(num_epochs):
    new_x, grad = update_step_gd(x_val, f, learning_rate)
    x_vals.append(new_x)
    fx_vals.append(f(new_x))
    x_val = new_x  # Update x_val for the next iteration

# Plot function
plt.figure()
x = np.linspace(-10, 10, 400)
plt.plot(x, f(x))

# Plot all points from gradient descent
plt.plot(x_vals, fx_vals, "go-", markersize=4, label="GD Steps")  # Green dots with lines

# Highlight initial and final points
plt.plot(x_vals[0], fx_vals[0], "ro", markersize=6, label="Initial Point")   # Red: Initial
plt.plot(x_vals[-1], fx_vals[-1], "o", color="orange", markersize=6, label="Final Point")  # Orange: Final

# Plot final tangent line
t_x = np.linspace(x_vals[-1] - 2, x_vals[-1] + 2, 10)
plt.plot(t_x, grad * t_x + (f(x_vals[-1]) - grad * x_vals[-1]), color="black", label="Final Tangent")

print("Final x:", x_vals[-1])
print("Final Grad:", grad)

plt.legend()
plt.show()
# Out:
# Final x: -0.05769549876950386
# Final Grad: -0.14411374692376716

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Initialize parameters
x_val = -5

# hyper parameters
learning_rate = 0.01
num_epochs = 20

# Lists to store x values and function values
x_vals = [x_val]
fx_vals = [f(x_val)]

# Step 2: Gradient Descent Loop
for _ in range(num_epochs):
    new_x, grad = update_step_gd(x_val, f, learning_rate)
    x_vals.append(new_x)
    fx_vals.append(f(new_x))
    x_val = new_x  # Update x_val for the next iteration

# Plot function
plt.figure()
x = np.linspace(-10, 10, 400)
plt.plot(x, f(x))

# Plot all points from gradient descent
plt.plot(x_vals, fx_vals, "go-", markersize=4, label="GD Steps")  # Green dots with lines

# Highlight initial and final points
plt.plot(x_vals[0], fx_vals[0], "ro", markersize=6, label="Initial Point")   # Red: Initial
plt.plot(x_vals[-1], fx_vals[-1], "o", color="orange", markersize=6, label="Final Point")  # Orange: Final

# Plot final tangent line
t_x = np.linspace(x_vals[-1] - 2, x_vals[-1] + 2, 10)
plt.plot(t_x, grad * t_x + (f(x_vals[-1]) - grad * x_vals[-1]), color="black", label="Final Tangent")

print("Final x:", x_vals[-1])
print("Final Grad:", grad)

plt.legend()
plt.show()
# Out:
# Final x: -3.3380564783777444
# Final Grad: -6.812258119150982

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Initialize parameters
x_val = -5

# hyper parameters
learning_rate = 0.9
num_epochs = 20

# Lists to store x values and function values
x_vals = [x_val]
fx_vals = [f(x_val)]

# Step 2: Gradient Descent Loop
for _ in range(num_epochs):
    new_x, grad = update_step_gd(x_val, f, learning_rate)
    x_vals.append(new_x)
    fx_vals.append(f(new_x))
    x_val = new_x  # Update x_val for the next iteration

# Plot function
plt.figure()
x = np.linspace(-10, 10, 400)
plt.plot(x, f(x))

# Plot all points from gradient descent
plt.plot(x_vals, fx_vals, "go-", markersize=4, label="GD Steps")  # Green dots with lines

# Highlight initial and final points
plt.plot(x_vals[0], fx_vals[0], "ro", markersize=6, label="Initial Point")   # Red: Initial
plt.plot(x_vals[-1], fx_vals[-1], "o", color="orange", markersize=6, label="Final Point")  # Orange: Final

# Plot final tangent line
t_x = np.linspace(x_vals[-1] - 2, x_vals[-1] + 2, 10)
plt.plot(t_x, grad * t_x + (f(x_vals[-1]) - grad * x_vals[-1]), color="black", label="Final Tangent")

print("Final x:", x_vals[-1])
print("Final Grad:", grad)
print("Final Value: ", f(x_vals[-1]))
plt.legend()
plt.show()
# Out:
# Final x: -0.05769549876894789
# Final Grad: 0.1441137469223707
# Final Value:  0.0033287705781976673
